# %% [markdown]
# ## Example

# %%
from crawler import Crawler, Queue

keywords = []
def findKeyword(url, data):
  if data is None:
    return
  
  if "internet" in data.lower():
    keywords.append(url)

def begin(soup):
  return soup.find("h2", id="See_also")

def end(sibling):
  return getattr(sibling.next_element, "name", None) == "h2"

crawler = Crawler()
crawler.search(
  url="https://en.wikipedia.org/wiki/Internet", 
  structure=Queue(),
  begin=begin, 
  end=end, 
  max_iter=500,
  get=findKeyword
)
# Out:
# Searching: 100%|██████████| 500/500 [02:47<00:00,  2.98it/s]

# %%
for el in crawler.getVisited():
  print(el.split("/")[-1])
# Out:
# Internet
# File:Crystal_Clear_app_linneighborhood.svg
# Portal:Internet
# File:The_Blue_Marble,_AS17-148-22727.jpg
# Portal:World
# Crowdfunding
# Crowdsourcing
# Cyberspace
# Darknet
# Deep_web
# Hyphanet
# Internet_industry_jargon
# Index_of_Internet-related_articles
# Internet_metaphors
# Internet_video
# Internets
# Outline_of_the_Internet
# Timeline_of_the_history_of_the_Internet
# Angel_investor
# Assurance_contract
# Business_models_for_open-source_software
# Comparison_of_crowdfunding_services
# Crowdfunding_in_video_games
# Cooperative_banking
# Equity_crowdfunding
# Fan-funded_music
# Group_buying
# Internet_begging
# List_of_highest-funded_crowdfunding_projects
# List_of_highest-funded_equity_crowdfunding_projects
# Microfinance
# Participatory_budgeting
# Peer-to-peer_lending
# Platform_cooperative
# Private_equity
# Revenue-based_financing
# Seed_money
# Threshold_pledge_system
# Chronolog
# Citizen_science
# Clickworkers
# Collaborative_innovation_network
# Collaborative_mapping
# Collective_consciousness
# Collective_intelligence
# Collective_problem_solving
# Commons-based_peer_production
# Crowd_computing
# Crowdcasting
# Crowdfixing
# Crowdsourcing_software_development
# Distributed_thinking
# Distributed_Proofreaders
# Flash_mob
# Folksonomy
# Gamification
# Government_crowdsourcing
# List_of_crowdsourcing_projects
# Models_of_collaborative_tagging
# Microcredit
# Participatory_democracy
# Participatory_monitoring
# Open_knowledge
# Prediction_market
# Smart_mob
# Social_collaboration
# Stone_Soup
# Teamwork
# Truecaller
# Virtual_collective_consciousness
# Virtual_volunteering
# Wisdom_of_the_crowd
# Wiki_survey
# Crowdsource_(app)
# Cyber-HUMINT
# Information_superhighway
# Internet_of_things
# Metaverse
# Simulated_reality
# Telepresence
# Virtual_world
# BlackBook_(social_network)
# Crypto-anarchism
# Cryptocurrency
# Darknet_market
# Dark_web
# Private_peer-to-peer
# Sneakernet
# Virtual_private_network
# Clearnet_(networking)
# DARPA%27s_Memex_program
# Deep_linking
# Deep_Web_Technologies
# Intellectual_dark_web
# Tor_(network)
# List_of_Tor_onion_services
# Portal:Free_and_open-source_software
# Peer-to-peer_web_hosting
# Rendezvous_protocol
# Anonymous_P2P
# Cypherpunk
# Distributed_file_system
# Freedom_of_information
# Friend-to-friend
# index.php?title=Hyphanet&action=edit&section=28
# GNUnet
# I2P
# InterPlanetary_File_System
# Java_Anon_Proxy
# Osiris_(Serverless_Portal_System)
# Perfect_Dark_(P2P)
# Share_(P2P)
# Winny
# Tahoe-LAFS
# ZeroNet
# Category:Computing_terminology
# List_of_computing_topics
# Template:Index_footer
# Template_talk:Index_footer
# Template:Index_footer
# Indices
# Indices#General_reference
# Indices#Culture_and_the_arts
# Indices#Geography_and_places
# Indices#Health_and_fitness
# Indices#History_and_events
# Index_of_law_articles
# Indices#Mathematics_and_logic
# Indices#Natural_and_physical_sciences
# Indices#People_and_self
# Indices#Philosophy_and_thinking
# Indices#Religion_and_belief_systems
# Indices#Society_and_social_sciences
# Indices#Technology_and_applied_sciences
# Series_of_tubes
# Portal:Journalism
# File:Noun-technology.svg
# Portal:Technology
# History_of_the_internet
# Live_streaming
# Livestreamed_news
# Over-the-top_media_service
# Streaming_media
# Video_clip_(online_media)
# Webcast
# YouTube
# Wikipedia:Wikimedia_sister_projects
# File:Wiktionary-logo-v2.svg
# Internet
# File:Commons-logo.svg
# Category:Internet
# File:Wikinews-logo.svg
# Category:Internet
# File:Wikiquote-logo.svg
# Internet
# File:Wikisource-logo.svg
# Internet
# File:Wikibooks-logo.svg
# Internet
# File:Wikiversity_logo_2017.svg
# Internet
# Outline_of_information_technology
# Deep_tech
# Entrepreneurship
# Pre-money_valuation
# Super_angel
# Venture_capital_financing
# Venture_funding
# Vulture_fund
# Contingency_market
# Crowd_funding
# Free_State_Project
# Kickstarter
# Micropatronage
# Preorder_economy
# File:Emblem-money.svg
# Portal:Business_and_Economics
# Commercial_use_of_copyleft_works
# Free_software#Business_model
# Open_Source_Development_Labs
# Open_business
# Open_innovation
# Software_monetization
# List_of_video_game_crowdfunding_projects
# Portal:Banks
# Building_society
# Credit_union
# Mutual_savings_bank
# Rotating_savings_and_credit_association
# Savings_and_loan_association
# List_of_European_cooperative_banks
# Alternative_Finance
# Comparison_of_crowd_funding_services
# List_of_highest_funded_equity_crowdfunding_projects
# Securities_offering
# Venture_round
# Direct-to-fan
# Freemium
# Free-to-play
# Open_Music_Model
# Economy_of_scale
# Group_purchasing_organization
# Save_Karyn
# One_red_paperclip
# Begslist.org
# The_Million_Dollar_Homepage
# Kickstarter#Top_projects_by_funds_raised
# Indiegogo#Top_projects_by_funds_raised
# Alternative_data
# Chit_fund
# Market_governance_mechanism
# Microcredit_for_water_supply_and_sanitation
# Microfinance_in_Tanzania
# Category:Microfinance_organizations
# Microgrant
# Microinsurance
# Pawnbroker
# Savings_bank
# Social_finance
# WWB_Colombia
# Civic_engagement
# Citizens%27_assembly
# Financial_referendum
# Participatory_economics
# Participatory_planning
# Tax_choice
# Alternative_finance
# Alternative_financial_services
# Customer_to_customer
# Non-bank_financial_institution
# Peer-to-peer_banking
# Self-Organized_Funding_Allocation
# Social_media_in_the_financial_services_sector
# Category:Peer-to-peer_lending_companies
# Cooperative
# Sharing_economy
# Solidarity_economy
# Unionized_cooperative
# Workers%27_self-management
# Common_ordinary_equity
# History_of_private_equity_and_venture_capital
# Holding_company
# List_of_private_equity_owned_companies_that_have_filed_for_bankruptcy
# Private_equity_fund
# Private_investment_in_public_equity
# Publicly_traded_private_equity
# Specialized_investment_fund
# Search_fund
# Vulture_capitalist
# Enshittification
# index.php?title=Private_equity&action=edit&section=42
# Institutional_Limited_Partners_Association
# American_Investment_Council
# Income_share_agreement
# Royalty_payment
# Digital_currency
# Series_A_round
# Venture_capital
# Copyright_social_conflict
# Portals
# File:Nuvola_apps_kalzium.svg
# Portal:Science
# File:Social_sciences.svg
# Portal:Society
# Independent_scientist
# Independent_scholar
# List_of_citizen_science_projects
# List_of_volunteer_computing_projects
# Open_science
# Open-source_intelligence
# Open-Source_Lab_(book)
# Outsider_art
# Public_participation_(decision_making)
# Reinventing_Discovery
# Popular_science
# Public_participation
# Scientific_instrument
# Polytely
# Swarm_intelligence
# Open_politics
# Symbolic_interactionism
# Community_of_practice
# Category:Collaborative_mapping
# Category:Virtual_globes
# Category:Web_mapping
# Cadastral_map
# Comparison_of_commercial_GPS_software
# Comparison_of_web_map_services
# Counter-mapping
# List_of_wikis
# Neogeography
# Participatory_3D_modelling
# Participatory_GIS
# Public_participation_GIS
# Virtual_globe
# Volunteered_geographic_information
# Humanitarian_OpenStreetMap_Team
# Abilene_paradox
# Agenda_21
# Anonymous_(group)
# Antonio_Gramsci
# Borg#Borg_Collective
# Collective_effervescence
# Collective_identity
# Collective_memory
# Collective_unconscious
# Communal_reinforcement
# Crowd_psychology
# Deep_social_mind
# Dharma
# #cite_note-20
# Egregor
# Global_brain
# Global_goals
# Group_behaviour
# Group_mind_(science_fiction)
# Groupthink
# Higher_consciousness
# Human_spirit
# Infodemic
# Materialism
# Noosphere
# Paradigm
# Paradigm_shift
# Peer_pressure
# Presence_(telepresence)
# Reality_tunnel
# Schema_(psychology)
# Shared_intentionality
# Social_justice
# Social_representation
# Superorganism
# Unanimism
# United_Nations
# V%C3%B6lkerpsychologie
# Zeitgeist
# index.php?title=Collective_intelligence&action=edit&section=49
# Civic_intelligence
# Collaborative_filtering
# Collective_decision-making
# Global_Consciousness_Project
# Knowledge_ecosystem
# Recommendation_system
# Social_commerce
# Social_epistemology
# Social_information_processing
# Stigmergy
# Raymond_Cattell#Innovations_and_accomplishments
# Think_tank
# Wiki
# Wikipedia
# index.php?title=Collective_intelligence&action=edit&section=50
# Bees_algorithm
# Cellular_automaton
# Collaborative_human_interpreter
# Collaborative_software
# Connectivity_(graph_theory)
# Enterprise_bookmarking
# Human-based_computation
# Open-source_software
# Organismic_computing
# Preference_elicitation
# index.php?title=Collective_intelligence&action=edit&section=51
# Customer_engagement
# Dispersed_knowledge
# Distributed_cognition
# Facilitation_(business)
# Facilitator
# Group_cognition
# Hundredth_monkey_effect
# Intersubjectivity
# Keeping_up_with_the_Joneses
# Library
# Library_of_Alexandria
# Meme
# Open-space_meeting
# Situated_cognition
# Portal:Philosophy
# Portal:Psychology
# Problem_solving
# Actuarial_science
# Analytical_skill
# Creative_problem-solving
# Coworking
# Crowdsolving
# Divergent_thinking
# Grey_problem
# Innovation
# Instrumentalism
# Problem-posing_education
# Problem_statement
# Problem_structuring_methods
# Structural_fix
# Subgoal_labeling
# Troubleshooting
# Wicked_problem
# Anti-rival_good
# Carr%E2%80%93Benkler_wager
# Co-creation
# Cognitive_Surplus
# Collaboration
# Collaborative_software_development_model
# Common_ownership
# Motivations_of_open_source_programmers
# Decentralized_planning_(economics)
# Distributed_manufacturing
# Fablab
# Gift_economy
# Here_Comes_Everybody_(book)
# Knowledge_commons
# Mass_collaboration
# Nonformal_learning
# Open_collaboration
# Peer_learning
# Peer_review
# Production_for_use
# Prosumer
# Open_manufacturing
# Open_music_model
# Open-source_hardware
# Social_peer-to-peer_processes
# Decentralized_computing
# Distributed_computing
# Broadcasting
# Narrowcasting
# Open_Innovation
# Placemaking
# City_repair_project
# Open-source_software_development
# Collaborative_intelligence
# Collaborative_Innovation_Networks
# Game_with_a_purpose
# Human_computer
# Human_Computer_Information_Retrieval
# Social_software
# Social_computing
# Social_organization
# Symbiotic_intelligence
# List_of_digital_library_projects
# Wikisource
# ReCAPTCHA
# Critical_mass_(sociodynamics)
# Crowd_manipulation
# Happening
# Improv_Everywhere
# Zap_(action)
# Flash_Crowd
# Larry_Niven
# Automatic_image_annotation
# Blogosphere
# Faceted_classification
# Hierarchical_clustering
# Semantic_annotation
# Semantic_similarity
# Thesaurus
# Weak_ontology
# Bartle_taxonomy_of_player_types
# Dark_pattern
# Egoboo
# Gamification_of_learning
# GNS_theory
# Crowdmapping#Examples
# List_of_grid_computing_projects
# List_of_free_and_open-source_Android_applications
# Knowledge_tagging
# Hashtag
# Count_Me_In_(charity)
# Crowd_sourcing
# Decentralized_finance
# Flat_rate_(finance)
# M-Pesa
# Payday_loan
# Project_Enterprise
# Solidarity_lending
# The_Women%27s_Development_Bank
# Oikocredit
# Collaborative_governance
# Deliberative_democracy
# Demarchy
# Green_politics
# Inclusive_Democracy
# Open_source_governance
# Participatory_action_research
# Participatory_culture
# Participatory_justice
# Public_incubator
# Public_sphere
# Radical_democracy
# Radical_transparency
# Sociocracy
# Workers%27_council
# Adaptive_management
# Biodiversity
# Bioregion
# Conservation_biology
# Conservation_ethic
# Conservation_movement
# Conservation_reliant_species
# Crowdmapping
# Ecology

# %%
print("Iterations:",crawler.maxIterations())
print("Max depth:", crawler.maxDepth())
# Out:
# Iterations: 500
# Max depth: 3

# %%
print("This url's contains keyword `internet`")
for url in keywords:
  print(url.split("/")[-1])
# Out:
# This url's contains keyword `internet`
# Internet
# File:Crystal_Clear_app_linneighborhood.svg
# Portal:Internet
# File:The_Blue_Marble,_AS17-148-22727.jpg
# Portal:World
# Crowdfunding
# Crowdsourcing
# Cyberspace
# Darknet
# Deep_web
# Hyphanet
# Internet_industry_jargon
# Index_of_Internet-related_articles
# Internet_metaphors
# Internet_video
# Internets
# Outline_of_the_Internet
# Timeline_of_the_history_of_the_Internet
# Angel_investor
# Business_models_for_open-source_software
# Comparison_of_crowdfunding_services
# Equity_crowdfunding
# Fan-funded_music
# Group_buying
# Internet_begging
# Microfinance
# Participatory_budgeting
# Peer-to-peer_lending
# Platform_cooperative
# Threshold_pledge_system
# Citizen_science
# Collaborative_innovation_network
# Collective_intelligence
# Collective_problem_solving
# Commons-based_peer_production
# Crowd_computing
# Crowdcasting
# Crowdsourcing_software_development
# Distributed_thinking
# Distributed_Proofreaders
# Flash_mob
# Folksonomy
# Government_crowdsourcing
# List_of_crowdsourcing_projects
# Microcredit
# Participatory_democracy
# Participatory_monitoring
# Open_knowledge
# Prediction_market
# Smart_mob
# Social_collaboration
# Truecaller
# Virtual_collective_consciousness
# Virtual_volunteering
# Wisdom_of_the_crowd
# Crowdsource_(app)
# Cyber-HUMINT
# Information_superhighway
# Internet_of_things
# Metaverse
# Simulated_reality
# Telepresence
# Virtual_world
# Crypto-anarchism
# Cryptocurrency
# Darknet_market
# Dark_web
# Private_peer-to-peer
# Sneakernet
# Virtual_private_network
# Clearnet_(networking)
# DARPA%27s_Memex_program
# Deep_linking
# Deep_Web_Technologies
# Tor_(network)
# List_of_Tor_onion_services
# Portal:Free_and_open-source_software
# Peer-to-peer_web_hosting
# Rendezvous_protocol
# Anonymous_P2P
# Cypherpunk
# Distributed_file_system
# Freedom_of_information
# Friend-to-friend
# GNUnet
# I2P
# InterPlanetary_File_System
# Java_Anon_Proxy
# Osiris_(Serverless_Portal_System)
# Perfect_Dark_(P2P)
# Share_(P2P)
# Winny
# ZeroNet
# Category:Computing_terminology
# List_of_computing_topics
# Indices
# Indices#General_reference
# Indices#Culture_and_the_arts
# Indices#Geography_and_places
# Indices#Health_and_fitness
# Indices#History_and_events
# Indices#Mathematics_and_logic
# Indices#Natural_and_physical_sciences
# Indices#People_and_self
# Indices#Philosophy_and_thinking
# Indices#Religion_and_belief_systems
# Indices#Society_and_social_sciences
# Indices#Technology_and_applied_sciences
# Series_of_tubes
# Portal:Journalism
# Portal:Technology
# History_of_the_internet
# Live_streaming
# Livestreamed_news
# Over-the-top_media_service
# Streaming_media
# Video_clip_(online_media)
# Webcast
# YouTube
# Internet
# Category:Internet
# Category:Internet
# Internet
# Internet
# Internet
# Internet
# Outline_of_information_technology
# Crowd_funding
# Kickstarter
# Micropatronage
# Preorder_economy
# Commercial_use_of_copyleft_works
# Free_software#Business_model
# Open_business
# Open_innovation
# Software_monetization
# List_of_video_game_crowdfunding_projects
# Portal:Banks
# Building_society
# Credit_union
# Comparison_of_crowd_funding_services
# Direct-to-fan
# Freemium
# Open_Music_Model
# Economy_of_scale
# Save_Karyn
# Begslist.org
# The_Million_Dollar_Homepage
# Kickstarter#Top_projects_by_funds_raised
# Indiegogo#Top_projects_by_funds_raised
# Pawnbroker
# Civic_engagement
# Customer_to_customer
# Self-Organized_Funding_Allocation
# Cooperative
# Sharing_economy
# History_of_private_equity_and_venture_capital
# Enshittification
# Royalty_payment
# Digital_currency
# Venture_capital
# Copyright_social_conflict
# Portals
# File:Social_sciences.svg
# Portal:Society
# List_of_volunteer_computing_projects
# Open_science
# Open-source_intelligence
# Outsider_art
# Public_participation_(decision_making)
# Reinventing_Discovery
# Popular_science
# Public_participation
# Scientific_instrument
# Swarm_intelligence
# Open_politics
# Symbolic_interactionism
# Community_of_practice
# Category:Web_mapping
# Comparison_of_web_map_services
# Counter-mapping
# List_of_wikis
# Neogeography
# Virtual_globe
# Volunteered_geographic_information
# Humanitarian_OpenStreetMap_Team
# Anonymous_(group)
# Antonio_Gramsci
# Collective_effervescence
# Collective_memory
# Collective_unconscious
# Communal_reinforcement
# Crowd_psychology
# Dharma
# Global_brain
# Global_goals
# Group_mind_(science_fiction)
# Groupthink
# Human_spirit
# Infodemic
# Noosphere
# Paradigm_shift
# Peer_pressure
# Presence_(telepresence)
# Superorganism
# United_Nations
# Zeitgeist
# Civic_intelligence
# Collaborative_filtering
# Global_Consciousness_Project
# Recommendation_system
# Social_commerce
# Social_epistemology
# Social_information_processing
# Stigmergy
# Think_tank
# Wiki
# Wikipedia
# Collaborative_software
# Enterprise_bookmarking
# Human-based_computation
# Open-source_software
# Customer_engagement
# Library
# Library_of_Alexandria
# Meme
# Situated_cognition
# Portal:Philosophy
# Portal:Psychology
# Coworking
# Crowdsolving
# Innovation
# Anti-rival_good
# Carr%E2%80%93Benkler_wager
# Co-creation
# Cognitive_Surplus
# Collaboration
# Common_ownership
# Decentralized_planning_(economics)
# Distributed_manufacturing
# Gift_economy
# Here_Comes_Everybody_(book)
# Knowledge_commons
# Mass_collaboration
# Open_collaboration
# Peer_learning
# Open_manufacturing
# Open_music_model
# Open-source_hardware
# Social_peer-to-peer_processes
# Decentralized_computing
# Distributed_computing
# Broadcasting
# Narrowcasting
# Open_Innovation
# Placemaking
# Open-source_software_development
# Collaborative_intelligence
# Collaborative_Innovation_Networks
# Game_with_a_purpose
# Human_computer
# Social_software
# Social_computing
# Symbiotic_intelligence
# List_of_digital_library_projects
# Wikisource
# ReCAPTCHA
# Crowd_manipulation
# Happening
# Improv_Everywhere
# Larry_Niven
# Automatic_image_annotation
# Blogosphere
# Semantic_annotation
# Semantic_similarity
# Dark_pattern
# Egoboo
# Crowdmapping#Examples
# List_of_free_and_open-source_Android_applications
# Knowledge_tagging
# Hashtag
# Crowd_sourcing
# Decentralized_finance
# M-Pesa
# Payday_loan
# Deliberative_democracy
# Demarchy
# Open_source_governance
# Participatory_culture
# Participatory_justice
# Public_incubator
# Public_sphere
# Radical_democracy
# Radical_transparency
# Workers%27_council
# Biodiversity
# Crowdmapping
# Ecology

# %% [markdown]
# ## Compare Stack vs Queue

# %%
from crawler import Crawler, Queue, Stack

def begin(soup):
  return soup.find("h2", id="See_also")

def end(sibling):
  return getattr(sibling.next_element, "name", None) == "h2"

# %%
keywords_queue = []
def findKeywordQueue(url, data):
  if data is None:
    return
  
  if "internet" in data.lower():
    keywords_queue.append(url)


queue = Crawler()
queue.search(
  url="https://en.wikipedia.org/wiki/Internet", 
  structure=Queue(),
  begin=begin, 
  end=end, 
  max_iter=1000,
  get=findKeywordQueue
)
# Out:
# Searching:  56%|█████▌    | 555/1000 [03:37<04:31,  1.64it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Collective_influence_algorithm&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Collective_influence_algorithm
# Searching:  63%|██████▎   | 627/1000 [04:18<03:37,  1.71it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Industrial_internet&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Industrial_internet
# Searching:  76%|███████▋  | 764/1000 [05:49<01:34,  2.50it/s]
# Failed to fetch http://i.dell.com/sites/doccontent/business/solutions/power/de/Documents/ps2q05-20040179-Saify-OE_de.pdf: 403 Client Error: Forbidden for url: https://i.dell.com/sites/doccontent/business/solutions/power/de/Documents/ps2q05-20040179-Saify-OE_de.pdf
# Searching:  77%|███████▋  | 769/1000 [06:11<20:04,  5.21s/it]
# Failed to fetch http://www.uobabylon.edu.iq/download/M.S%202013-2014/Operating_System_Concepts,_8th_Edition%5BA4%5D.pdf: 404 Client Error: Not Found for url: https://www.uobabylon.edu.iq:443/download/M.S%202013-2014/Operating_System_Concepts,_8th_Edition%5BA4%5D.pdf
# Searching: 100%|██████████| 1000/1000 [08:15<00:00,  2.02it/s]

# %%
keywords_stack = []
def findKeywordStack(url, data):
  if data is None:
    return
  
  if "internet" in data.lower():
    keywords_stack.append(url)


stack = Crawler()
stack.search(
  url="https://en.wikipedia.org/wiki/Internet", 
  structure=Stack(),
  begin=begin, 
  end=end, 
  max_iter=1000,
  get=findKeywordStack
)
# Out:
# Searching:   6%|▋         | 64/1000 [00:15<07:16,  2.15it/s]
# Failed to fetch https://stats.wikimedia.org/EN/Sitemap: 404 Client Error: Not Found for url: https://stats.wikimedia.org/EN/Sitemap
# Searching:  16%|█▌        | 156/1000 [00:50<05:17,  2.66it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Arbitration_Committee/Discretionary_sanctions/2021_review&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Arbitration_Committee/Discretionary_sanctions/2021_review
# Searching:  16%|█▌        | 157/1000 [00:51<07:17,  1.93it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Arbitration_Committee/Discretionary_sanctions/2013_review&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Arbitration_Committee/Discretionary_sanctions/2013_review
# Searching:  50%|█████     | 502/1000 [03:03<01:48,  4.60it/s]
# Failed to fetch https://www.nli.org.il/en/authorities/987007558512305171: 403 Client Error: Forbidden for url: https://www.nli.org.il/en/authorities/987007558512305171
# Searching:  74%|███████▍  | 740/1000 [04:29<01:12,  3.59it/s]
# Failed to fetch https://www.nli.org.il/en/authorities/987007530447705171: 403 Client Error: Forbidden for url: https://www.nli.org.il/en/authorities/987007530447705171
# Searching:  84%|████████▍ | 840/1000 [05:09<01:20,  1.99it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Index_of_Vietnam-related_articles&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Index_of_Vietnam-related_articles
# Searching:  84%|████████▍ | 843/1000 [05:14<03:42,  1.42s/it]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Index_of_Turkmenistan-related_articles&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Index_of_Turkmenistan-related_articles
# Searching:  86%|████████▌ | 858/1000 [05:32<01:33,  1.51it/s]
# Failed to fetch https://www.nli.org.il/en/authorities/987007566060505171: 403 Client Error: Forbidden for url: https://www.nli.org.il/en/authorities/987007566060505171
# Searching:  97%|█████████▋| 968/1000 [06:09<00:14,  2.24it/s]
# Failed to fetch https://en.wikipedia.org/w/index.php?title=Hugo_(programming_language)&action=edit&redlink=1: 404 Client Error: Not Found for url: https://en.wikipedia.org/wiki/Hugo_(programming_language)
# Searching: 100%|██████████| 1000/1000 [06:23<00:00,  2.61it/s]

# %%
print("Links with keyword for Queue:", len(keywords_queue))
print("Max Depth for Queue:", queue.maxDepth())
print("------------------------")
print("Links with keyword for Stack:", len(keywords_stack))
print("Max Depth for Stack:", stack.maxDepth())
print("------------------------")
if(len(keywords_queue) < len(keywords_stack)):
  print("Stack found more links")
else:
  print("Queue found more links")
# Out:
# Links with keyword for Queue: 545
# Max Depth for Queue: 3
# ------------------------
# Links with keyword for Stack: 289
# Max Depth for Stack: 483
# ------------------------
# Queue found more links
